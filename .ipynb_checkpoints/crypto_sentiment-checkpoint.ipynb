# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Sarah\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
load_dotenv('../../keys.env')
from newsapi import NewsApiClient
api_key = os.getenv('NEWS_API')

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key = api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_articles = newsapi.get_everything(
    q= 'bitcoin',
    language = 'en',
    page_size = 100,
    sort_by = 'relevancy')

# %%
# Fetch the Ethereum news articles
ethereum_articles = newsapi.get_everything(
    q= 'ethereum',
    language = 'en',
    page_size = 100,
    sort_by = 'relevancy')

# %%
# Define sentiment scores
# Define sentiment scores function
def sentiment_score(articles_list):
    sentiments_list = []

    for article in articles_list["articles"]:
        try:
            text = article["content"]
            date = article["publishedAt"][:10]
            sentiment = analyzer.polarity_scores(text)
            compound = sentiment["compound"]
            pos = sentiment["pos"]
            neu = sentiment["neu"]
            neg = sentiment["neg"]

            sentiments_list.append({
                "text": text,
                "date": date,
                "compound": compound,
                "positive": pos,
                "negative": neg,
                "neutral": neu

            })

        except AttributeError:
            pass

        
    # Create DataFrame
    senitment_df = pd.DataFrame(sentiments_list)

    # Reorder DataFrame columns
    cols = ["date", "text", "compound", "positive", "negative", "neutral"]
    senitment_df = senitment_df[cols]
    
    return senitment_df

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_sentiment_score = sentiment_score(bitcoin_articles)
bitcoin_sentiment_score.sort_values(by= ["date"], ascending=True).head()
# Out:
#           date                                               text  compound  \
# 29  2021-11-26  LONDON, Nov 26 (Reuters) - Bitcoin tumbled alm...   -0.5106
# 40  2021-11-26  SAN SALVADOR, Nov 26 (Reuters) - El Salvador P...    0.3400
# 43  2021-11-26  Bitcoinfell 9% in the last day lowering its va...    0.3642
# 44  2021-11-26  Posted \r\nFrom volcano-powered bitcoin bonds,...    0.0000
# 95  2021-11-27  Matthew Heard, a software engineer from San Jo...   -0.2960
#
#     positive  negative  neutral
# 29     0.050     0.148    0.801
# 40     0.068     0.000    0.932
# 43     0.156     0.099    0.745
# 44     0.000     0.000    1.000
# 95     0.000     0.058    0.942

# %%
# Create the Ethereum sentiment scores DataFrame
ethereum_sentiment_score = sentiment_score(ethereum_articles)
ethereum_sentiment_score.sort_values(by= ["date"], ascending=True).head()
# Out:
#           date                                               text  compound  \
# 56  2021-11-26  Representations of cryptocurrencies Bitcoin, E...    0.0000
# 94  2021-11-27  Sam Bankman-Fried cofounded FTX in 2019 and is...    0.3612
# 54  2021-11-29  The photo shows physical imitations of cryptoc...    0.0000
# 75  2021-11-29  Shina inu dog.AP Photo/Shizuo Kambayashi\r\nKr...   -0.6908
# 27  2021-11-29  Vitalik Buterin. Source: A video screenshot, Y...    0.4588
#
#     positive  negative  neutral
# 56     0.000     0.000    1.000
# 94     0.067     0.000    0.933
# 54     0.000     0.000    1.000
# 75     0.000     0.164    0.836
# 27     0.097     0.000    0.903

# %%
# Describe the Bitcoin Sentiment
bitcoin_sentiment_score.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.104764    0.063740    0.038870    0.897370
# std      0.366297    0.067212    0.057822    0.091782
# min     -0.802000    0.000000    0.000000    0.660000
# 25%     -0.025800    0.000000    0.000000    0.843500
# 50%      0.000000    0.051000    0.000000    0.913000
# 75%      0.401900    0.114000    0.070250    1.000000
# max      0.790600    0.230000    0.246000    1.000000

# %%
# Describe the Ethereum Sentiment
ethereum_sentiment_score.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.162882    0.076060    0.034060    0.889820
# std      0.394589    0.080037    0.055335    0.096536
# min     -0.802000    0.000000    0.000000    0.640000
# 25%      0.000000    0.000000    0.000000    0.823750
# 50%      0.121700    0.068500    0.000000    0.918500
# 75%      0.406800    0.126000    0.063250    0.961500
# max      0.946000    0.360000    0.246000    1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Eth had the highest mean positive score.
#
# Q: Which coin had the highest compound score?
#
# A: Eth also had the highest max compound score.
#
# Q. Which coin had the highest positive score?
#
# A: Eth had the highest max positive score.

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
stop_words = set(stopwords.words('english'))

# Expand the default stopwords list if necessary
stop_words2 = {'said'}

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation from text
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)
   
    # Create a tokenized list of the words
    re_words = word_tokenize(re_clean)
    
    # Lemmatize words into root words
    lemmatize = [lemmatizer.lemmatize(word) for word in re_words]
    lemmatize_verbs = [lemmatizer.lemmatize(word, pos ='v') for word in lemmatize]
   
    # Convert the words to lowercase & Remove the stop words
    tokens = [word.lower() for word in lemmatize_verbs 
                  if word.lower() not in stop_words.union(stop_words2)]

    return tokens

# %%
# Create a new tokens column for Bitcoin
bitcoin_sentiment_score['token'] = [tokenizer(text) for text in bitcoin_sentiment_score['text']]
bitcoin_sentiment_score.head()
# Out:
#          date                                               text  compound  \
# 0  2021-12-12  Image source, AFP via Getty Images\r\nImage ca...   -0.4019
# 1  2021-12-06  The plant opening northeast of Niagara Falls t...    0.0000
# 2  2021-12-01  Earlier this year, Nothing released a pair of ...    0.5106
# 3  2021-12-23  Dec 23 (Reuters) - The U.S. Securities and Exc...    0.5859
# 4  2021-12-12  People aren't done hijacking major politicians...    0.5267
#
#    positive  negative  neutral  \
# 0     0.000     0.078    0.922
# 1     0.000     0.000    1.000
# 2     0.099     0.000    0.901
# 3     0.142     0.000    0.858
# 4     0.112     0.000    0.888
#
#                                                token
# 0  [image, source, afp, via, getty, imagesimage, ...
# 1  [plant, open, northeast, niagara, falls, month...
# 2  [earlier, year, nothing, release, pair, relati...
# 3  [dec, reuters, us, securities, exchange, commi...
# 4  [people, arent, hijack, major, politician, twi...

# %%
# Create a new tokens column for Ethereum
ethereum_sentiment_score['token'] = [tokenizer(text) for text in ethereum_sentiment_score['text']]
ethereum_sentiment_score.head()
# Out:
#          date                                               text  compound  \
# 0  2021-12-02  Blockchain startup MonoX Finance said on Wedne...   -0.0516
# 1  2021-11-30  On Monday, Budweiser joined the non-fungible t...   -0.1531
# 2  2021-12-01  Earlier this year, Nothing released a pair of ...    0.5106
# 3  2021-12-10  White Castle double cheeseburger.Erin McDowell...    0.0000
# 4  2021-12-10  Nicholas Merten , an expert in cryptography, p...    0.4939
#
#    positive  negative  neutral  \
# 0     0.074     0.079    0.847
# 1     0.000     0.045    0.955
# 2     0.099     0.000    0.901
# 3     0.000     0.000    1.000
# 4     0.119     0.000    0.881
#
#                                                token
# 0  [blockchain, startup, monox, finance, say, wed...
# 1  [monday, budweiser, join, nonfungible, token, ...
# 2  [earlier, year, nothing, release, pair, relati...
# 3  [white, castle, double, cheeseburgererin, mcdo...
# 4  [nicholas, merten, expert, cryptography, predi...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
def bigramize(sentiment_score_df, N):    
    corpus = [ ' '.join(list) for list in sentiment_score_df['token']]
    big_string =  ' '.join(corpus)
    token = word_tokenize(big_string)
    bigram = ngrams(token, n= N)
    
    return bigram

# %%
# Generate the Bitcoin N-grams where N=2
bitcoin_bigram = bigramize(bitcoin_sentiment_score, 2)

# %%
# Generate the Ethereum N-grams where N=2
ethereum_bigram = bigramize(ethereum_sentiment_score, 2)

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
bitcoin_bigram_count = pd.DataFrame(token_count(bitcoin_bigram,10))
bitcoin_bigram_count.head(10)

# %%
# Use token_count to get the top 10 words for Ethereum
ethereum_bigram_count = pd.DataFrame(token_count(ethereum_bigram,10))
ethereum_bigram_count.head(10)

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
btc_text = ' '.join(bitcoin_sentiment_score.text)
btc_processed = tokenizer(btc_text)
btc_ngrams = Counter(ngrams(btc_processed, n = 2))
print(dict(btc_ngrams))
# Out:
# {('image', 'source'): 2, ('source', 'afp'): 1, ('afp', 'via'): 1, ('via', 'getty'): 1, ('getty', 'imagesimage'): 2, ('imagesimage', 'caption'): 2, ('caption', 'modi'): 1, ('modi', 'ha'): 1, ('ha', 'ha'): 1, ('ha', 'million'): 1, ('million', 'twitter'): 1, ('twitter', 'followersindian'): 1, ('followersindian', 'prime'): 1, ('prime', 'minister'): 2, ('minister', 'narendra'): 2, ('narendra', 'modis'): 2, ('modis', 'twitter'): 2, ('twitter', 'account'): 3, ('account', 'wa'): 1, ('wa', 'hack'): 1, ('hack', 'message'): 1, ('message', 'say'): 1, ('say', 'india'): 1, ('india', 'ha'): 1, ('ha', 'char'): 1, ('char', 'plant'): 1, ('plant', 'open'): 1, ('open', 'northeast'): 1, ('northeast', 'niagara'): 1, ('niagara', 'falls'): 1, ('falls', 'month'): 1, ('month', 'somerset'): 1, ('somerset', 'ny'): 1, ('ny', 'part'): 1, ('part', 'million'): 1, ('million', 'project'): 1, ('project', 'terawulf'): 1, ('terawulf', 'bitcoin'): 1, ('bitcoin', 'mine'): 3, ('mine', 'company'): 1, ('company', 'project'): 1, ('project', 'also'): 1, ('also', 'include'): 1, ('include', 'propose'): 1, ('propose', 'megawatt'): 1, ('megawatt', 'char'): 1, ('char', 'earlier'): 1, ('earlier', 'year'): 2, ('year', 'nothing'): 1, ('nothing', 'release'): 1, ('release', 'pair'): 1, ('pair', 'relatively'): 1, ('relatively', 'cheap'): 1, ('cheap', 'ear'): 1, ('ear', 'earbuds'): 3, ('earbuds', 'fun'): 1, ('fun', 'transparent'): 1, ('transparent', 'case'): 1, ('case', 'wireless'): 1, ('wireless', 'charge'): 1, ('charge', 'decent'): 1, ('decent', 'sound'): 1, ('sound', 'quality'): 1, ('quality', 'company'): 1, ('company', 'create'): 1, ('create', 'oneplus'): 1, ('oneplus', 'cofounde'): 1, ('cofounde', 'char'): 1, ('char', 'dec'): 9, ('dec', 'reuters'): 16, ('reuters', 'us'): 2, ('us', 'securities'): 1, ('securities', 'exchange'): 1, ('exchange', 'commission'): 1, ('commission', 'veto'): 1, ('veto', 'two'): 1, ('two', 'proposal'): 1, ('proposal', 'offer'): 1, ('offer', 'bitcoin'): 1, ('bitcoin', 'exchangetraded'): 1, ('exchangetraded', 'fund'): 1, ('fund', 'deal'): 1, ('deal', 'blow'): 1, ('blow', 'market'): 1, ('market', 'participant'): 1, ('participant', 'hop'): 1, ('hop', 'agency'): 1, ('agency', 'would'): 1, ('would', 'green'): 1, ('green', 'char'): 1, ('char', 'people'): 1, ('people', 'arent'): 1, ('arent', 'hijack'): 1, ('hijack', 'major'): 1, ('major', 'politician'): 1, ('politician', 'twitter'): 1, ('account', 'financial'): 1, ('financial', 'gain'): 1, ('gain', 'techcrunch'): 1, ('techcrunch', 'report'): 1, ('report', 'intruder'): 1, ('intruder', 'temporarily'): 1, ('temporarily', 'seize'): 1, ('seize', 'control'): 1, ('control', 'indian'): 1, ('indian', 'prime'): 1, ('account', 'char'): 1, ('char', 'representation'): 3, ('representation', 'cryptocurrency'): 1, ('cryptocurrency', 'bitcoin'): 3, ('bitcoin', 'see'): 3, ('see', 'illustration'): 1, ('illustration', 'take'): 4, ('take', 'november'): 1, ('november', 'reutersdado'): 1, ('reutersdado', 'ruvicillustrationdec'): 1, ('ruvicillustrationdec', 'reuters'): 1, ('reuters', 'bitcoin'): 7, ('bitcoin', 'rise'): 2, ('rise', 'sunday'): 1, ('sunday', 'reclaim'): 1, ('reclaim', 'level'): 1, ('level', 'char'): 1, ('char', 'reuters'): 1, ('reuters', 'computer'): 1, ('computer', 'scientist'): 5, ('scientist', 'ha'): 3, ('ha', 'claim'): 3, ('claim', 'inventor'): 4, ('inventor', 'bitcoin'): 4, ('bitcoin', 'largely'): 3, ('largely', 'prevail'): 3, ('prevail', 'monday'): 1, ('monday', 'florida'): 1, ('florida', 'jury'): 3, ('jury', 'trial'): 3, ('trial', 'whether'): 3, ('whether', 'estate'): 3, ('estate', 'former'): 3, ('former', 'business'): 4, ('business', 'partner'): 3, ('partner', 'deserve'): 3, ('deserve', 'half'): 3, ('half', 'char'): 3, ('char', 'available'): 1, ('available', 'price'): 1, ('price', 'december'): 1, ('december', 'ththe'): 1, ('ththe', 'ear'): 1, ('earbuds', 'case'): 1, ('case', 'blackimage'): 1, ('blackimage', 'nothingnothings'): 1, ('nothingnothings', 'ear'): 1, ('earbuds', 'launch'): 1, ('launch', 'earlier'): 1, ( ...

# %%
# Generate the Ethereum N-grams where N=2
eth_text = ' '.join(ethereum_sentiment_score.text)
eth_processed = tokenizer(eth_text)
eth_ngrams = Counter(ngrams(eth_processed, n = 2))
print(dict(eth_ngrams))
# Out:
# {('blockchain', 'startup'): 1, ('startup', 'monox'): 2, ('monox', 'finance'): 2, ('finance', 'say'): 2, ('say', 'wednesday'): 3, ('wednesday', 'hacker'): 2, ('hacker', 'steal'): 2, ('steal', 'million'): 2, ('million', 'exploit'): 2, ('exploit', 'bug'): 2, ('bug', 'software'): 2, ('software', 'service'): 2, ('service', 'us'): 2, ('us', 'draft'): 2, ('draft', 'smart'): 2, ('smart', 'contractsthis'): 1, ('contractsthis', 'story'): 1, ('story', 'originally'): 1, ('originally', 'appear'): 1, ('appear', 'ars'): 1, ('ars', 'te'): 1, ('te', 'char'): 1, ('char', 'monday'): 1, ('monday', 'budweiser'): 1, ('budweiser', 'join'): 1, ('join', 'nonfungible'): 1, ('nonfungible', 'token'): 5, ('token', 'craze'): 1, ('craze', 'launch'): 1, ('launch', 'first'): 2, ('first', 'collection'): 1, ('collection', 'unique'): 1, ('unique', 'piece'): 1, ('piece', 'digital'): 1, ('digital', 'artdepictions'): 1, ('artdepictions', 'beer'): 1, ('beer', 'sell'): 1, ('sell', 'hundred'): 1, ('hundred', 'dollar'): 1, ('dollar', 'eachdub'): 1, ('eachdub', 'char'): 1, ('char', 'earlier'): 1, ('earlier', 'year'): 2, ('year', 'nothing'): 1, ('nothing', 'release'): 1, ('release', 'pair'): 1, ('pair', 'relatively'): 1, ('relatively', 'cheap'): 1, ('cheap', 'ear'): 1, ('ear', 'earbuds'): 4, ('earbuds', 'fun'): 1, ('fun', 'transparent'): 1, ('transparent', 'case'): 1, ('case', 'wireless'): 1, ('wireless', 'charge'): 1, ('charge', 'decent'): 1, ('decent', 'sound'): 1, ('sound', 'quality'): 1, ('quality', 'company'): 1, ('company', 'create'): 1, ('create', 'oneplus'): 1, ('oneplus', 'cofounde'): 1, ('cofounde', 'char'): 1, ('char', 'white'): 1, ('white', 'castle'): 2, ('castle', 'double'): 1, ('double', 'cheeseburgererin'): 1, ('cheeseburgererin', 'mcdowellinsiderthe'): 1, ('mcdowellinsiderthe', 'list'): 1, ('list', 'name'): 1, ('name', 'brand'): 1, ('brand', 'get'): 1, ('get', 'crypto'): 1, ('crypto', 'growsfast'): 1, ('growsfast', 'food'): 1, ('food', 'chain'): 1, ('chain', 'white'): 1, ('castle', 'announce'): 1, ('announce', 'twitter'): 1, ('twitter', 'register'): 1, ('register', 'domain'): 1, ('domain', 'name'): 1, ('name', 'th'): 1, ('th', 'char'): 3, ('char', 'nicholas'): 1, ('nicholas', 'merten'): 1, ('merten', 'expert'): 1, ('expert', 'cryptography'): 1, ('cryptography', 'predict'): 1, ('predict', 'digital'): 1, ('digital', 'currency'): 3, ('currency', 'ethereum'): 1, ('ethereum', 'overtake'): 1, ('overtake', 'bitcoin'): 1, ('bitcoin', 'market'): 1, ('market', 'reach'): 1, ('reach', 'highest'): 1, ('highest', 'value'): 1, ('value', 'since'): 1, ('since', 'may'): 1, ('may', 'clarify'): 1, ('clarify', 'e'): 1, ('e', 'char'): 1, ('char', 'people'): 1, ('people', 'around'): 1, ('around', 'world'): 1, ('world', 'still'): 1, ('still', 'search'): 1, ('search', 'information'): 1, ('information', 'covid'): 1, ('covid', 'pandemic'): 1, ('pandemic', 'topic'): 1, ('topic', 'dominate'): 1, ('dominate', 'googles'): 1, ('googles', 'year'): 1, ('year', 'search'): 2, ('search', 'like'): 1, ('like', 'cricket'): 1, ('cricket', 'squid'): 1, ('squid', 'game'): 1, ('game', 'matches'): 1, ('matches', 'worl'): 1, ('worl', 'char'): 1, ('char', 'wait'): 2, ('wait', 'finally'): 2, ('finally', 'yearlong'): 2, ('yearlong', 'delay'): 2, ('delay', 'xboxs'): 2, ('xboxs', 'iconic'): 2, ('iconic', 'hero'): 2, ('hero', 'master'): 2, ('master', 'chief'): 2, ('chief', 'back'): 2, ('back', 'halo'): 2, ('halo', 'infinite'): 2, ('infinite', 'new'): 2, ('new', 'toy'): 2, ('toy', 'fight'): 2, ('fight', 'mechanic'): 2, ('mechanic', 'many'): 2, ('many', 'player'): 2, ('player', 'also'): 2, ('also', 'benefit'): 2, ('benefit', 'majo'): 2, ('majo', 'char'): 2, ('char', 'microstrategy'): 1, ('microstrategy', 'ceo'): 1, ('ceo', 'michael'): 1, ('michael', 'saylorjoe'): 1, ('saylorjoe', 'raedlegetty'): 1, ('raedlegetty', 'imagesullithe'): 1, ('imagesullithe', 'lack'): 1, ('lack', 'spot'): 1, ('spot', 'bitcoin'): 1, ('bitcoin', 'etf'): 1, ('etf', 'mean'): 1, ('mean', 'investor'): 1, ('investor', 'look'): 1, ('look', ...

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
token_count(btc_processed)
# Out:
# [('char', 95), ('bitcoin', 46), ('reuters', 28)]

# %%
# Use token_count to get the top 10 words for Ethereum
token_count(eth_processed)
# Out:
# [('char', 97), ('cryptocurrency', 21), ('ha', 17)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
def bigstring(sentiment_score_df):    
    corpus = [ ' '.join(list) for list in sentiment_score_df['token']]
    big_string =  ' '.join(corpus)
    
    return big_string

input_bitcoin = bigstring(bitcoin_sentiment_score)

wc_bit = WordCloud(width=1200, height=800, max_words=50).generate(input_bitcoin)
plt.imshow(wc_bit);

# %%
# Generate the Ethereum word cloud
input_eth = bigstring(ethereum_sentiment_score)

wc_eth = WordCloud(width=1200, height=800, max_words=50).generate(input_eth)
plt.imshow(wc_eth);

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
corpus_bitcoin = ''
for text in bitcoin_sentiment_score['text']:
    corpus_bitcoin += text + ' '

# %%
# Run the NER processor on all of the text
tokens_bitcoin = nlp(corpus_bitcoin)

# Add a title to the document
tokens_bitcoin.user_data["title"] = "Bitcoin's news named entity recognition"

# %%
# Render the visualization
displacy.render(tokens_bitcoin, style="ent")
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin's news named entity recognition</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Image source,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AFP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  via
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Getty Images
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>Image caption,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Modi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  has has
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than 70 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# </br>
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Indian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  Prime Minister
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Narendra Modi's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  account was hacked with a message saying
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  ha… [+854 chars] The plant opening northeast of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Niagara Falls
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Somerset
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     N.Y.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , is part of a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $550 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  project by
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Terawulf
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , a Bitcoin mining company. The project also includes a proposed
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     150-megawatt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  … [+1514 chars]
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Earlier this year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , Nothing released a pair of relatively cheap $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     99
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  Ear 1 earbuds with a fun transparent case, wireless charging and decent sound quality. Now, the company (created by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     OnePlus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  cofounde… [+1395 chars]
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dec 23
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) -
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The U.S. Securities and Exchange Commission
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  vetoed
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  proposals to offer bitcoin exchange-traded funds, dealing a blow to market participants who had hoped the agency would green … [+1769 chars] People aren't done hijacking major politicians'
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twit

# %%
# List all Entities
list_ent_bitcoin = [(ent.text , ent.label_) for ent in tokens_bitcoin.ents]
list_ent_bitcoin
# Out:
# [('AFP', 'ORG'),
#  ('Getty Images', 'ORG'),
#  ('Modi', 'GPE'),
#  ('more than 70 million', 'MONEY'),
#  ('Twitter', 'PRODUCT'),
#  ('Indian', 'NORP'),
#  ("Narendra Modi's", 'PERSON'),
#  ('Twitter', 'PRODUCT'),
#  ('India', 'GPE'),
#  ('Niagara Falls', 'PERSON'),
#  ('this month', 'DATE'),
#  ('Somerset', 'GPE'),
#  ('N.Y.', 'GPE'),
#  ('$550 million', 'MONEY'),
#  ('Terawulf', 'DATE'),
#  ('150-megawatt', 'QUANTITY'),
#  ('Earlier this year', 'DATE'),
#  ('99', 'MONEY'),
#  ('OnePlus', 'ORG'),
#  ('Dec 23', 'DATE'),
#  ('Reuters', 'ORG'),
#  ('The U.S. Securities and Exchange Commission', 'ORG'),
#  ('two', 'CARDINAL'),
#  ('Twitter', 'PRODUCT'),
#  ('TechCrunch', 'ORG'),
#  ('Indian', 'NORP'),
#  ("Narendra Modi's", 'PERSON'),
#  ('Twitter', 'PRODUCT'),
#  ('+1087', 'CARDINAL'),
#  ('November 29, 2021', 'DATE'),
#  ('REUTERS', 'ORG'),
#  ('Dado Ruvic/IllustrationDec', 'PERSON'),
#  ('12', 'CARDINAL'),
#  ('Reuters', 'ORG'),
#  ('Sunday', 'DATE'),
#  ('above $50,000', 'MONEY'),
#  ('Reuters', 'ORG'),
#  ('Monday', 'DATE'),
#  ('Florida', 'GPE'),
#  ('half', 'CARDINAL'),
#  ('99', 'MONEY'),
#  ('December 13th', 'DATE'),
#  ('The Ear 1', 'WORK_OF_ART'),
#  ('Nothings Ear 1', 'PERSON'),
#  ('earlier this year', 'DATE'),
#  ('Dec 4', 'DATE'),
#  ('Reuters', 'ORG'),
#  ('8.4%', 'PERCENT'),
#  ('49,228.82', 'MONEY'),
#  ('20:01', 'CARDINAL'),
#  ('Saturday', 'DATE'),
#  ('4,514.87', 'MONEY'),
#  ('Bitcoin', 'PERSON'),
#  ('28.7%', 'PERCENT'),
#  ('fifth', 'ORDINAL'),
#  ('Saturday', 'DATE'),
#  ('nearly a billion dollars', 'MONEY'),
#  ('fifth', 'ORDINAL'),
#  ('Saturday', 'DATE'),
#  ('nearly a billion dollars', 'MONEY'),
#  ('Reuters', 'ORG'),
#  ('5.5%', 'PERCENT'),
#  ('53,435.9', 'MONEY'),
#  ('22:04', 'CARDINAL'),
#  ('Friday', 'DATE'),
#  ('3,112.06', 'MONEY'),
#  ('Bitcoin', 'PERSON'),
#  ('22.6%', 'PERCENT'),
#  ('Bitcoin', 'PERSON'),
#  ('October 19, 2021', 'DATE'),
#  ('REUTERS', 'ORG'),
#  ('Reuters', 'ORG'),
#  ('9.29%', 'PERCENT'),
#  ('48,752.15', 'MONEY'),
#  ('almost 5%', 'PERCENT'),
#  ('Monday', 'DATE'),
#  ('the start of the week', 'DATE'),
#  ('a bruising weekend', 'DATE'),
#  ('one', 'CARDINAL'),
#  ('fifth', 'ORDINAL'),
#  ('this week', 'DATE'),
#  ('Florida', 'GPE'),
#  ('half', 'CARDINAL'),
#  ('this week', 'DATE'),
#  ('Florida', 'GPE'),
#  ('half', 'CARDINAL'),
#  ('CIA', 'ORG'),
#  ('last week', 'DATE'),
#  ('10 minutes or so', 'TIME'),
#  ('David Gerard', 'PERSON'),
#  ('Satoshi', 'PERSON'),
#  ('Getty', 'ORG'),
#  ('Monday', 'DATE'),
#  ('daily', 'DATE'),
#  ('Cryptocurrencies', 'ORG'),
#  ('this weekend', 'DATE'),
#  ('14%', 'PERCENT'),
#  ('the weekend', 'DATE'),
#  ('$42K', 'MONEY'),
#  ('9000', 'MONEY'),
#  ('an hour', 'TIME'),
#  ('MEXICO CITY', 'GPE'),
#  ('Dec 17', 'DATE'),
#  ('Reuters', 'ORG'),
#  ('Mexico', 'GPE'),
#  ('Grupo Elektra', 'ORG'),
#  ('Latin America', 'LOC'),
#  ('Ele', 'PERSON'),
#  ('A decade ago', 'DATE'),
#  ('Monday', 'DATE'),
#  ('Budweiser', 'ORG'),
#  ('first', 'ORDINAL'),
#  ('hundreds of dollars', 'MONEY'),
#  ('Bitcoin', 'PERSON'),
#  ('Reuters', 'ORG'),
#  ('NEW YORK', 'GPE'),
#  ('HONG KONG', 'GPE'),
#  ('Reuters', 'ORG'),
#  ('almost 5%', 'PERCENT'),
#  ('Monday', 'DATE'),
#  ('the start of the week', 'DATE'),
#  ('a bruising weekend', 'DATE'),
#  ('MicroStrategy', 'ORG'),
#  ('Michael SaylorJoe Raedle/Getty Images', 'PERSON'),
#  ('ETF', 'ORG'),
#  ('LONDON', 'GPE'),
#  ('Reuters', 'ORG'),
#  ('almost 8%', 'PERCENT'),
#  ('Friday', 'DATE'),
#  ('Kessler Topaz Meltzer &', 'ORG'),
#  ('Check', 'GPE'),
#  ('LLP', 'ORG'),
#  ('BitcoinFrancesco Carta', 'PERSON'),
#  ('Cryptocurrencies', 'ORG'),
#  ('Monday', 'DATE'),
#  ('late last week', 'DATE'),
#  ('the Danube River', 'LOC'),
#  ('10', 'CARDINAL'),
#  ('the Opening Bell', 'ORG'),
#  ('Insider', 'PERSON'),
#  ('Android', 'ORG'),
#  ('David Solomon', 'PERSON'),
#  ('Goldman Sachs', 'ORG'),
#  ('Matt Winkelmeyer', 'PERSON'),
#  ('Getty Images', 'ORG'),
#  ('the next couple of years', 'DATE'),
#  ('a third day', 'DATE'),
#  ('Tuesday', 'DATE'),
#  ('50,000', 'MONEY'),
#  ('20%', 'PERCENT'),
#  ('the weekend', 'DATE'),
#  ('Charlie Munger', 'PERSON'),
#  ('one', 'CARDINAL'),
#  ("Warren Buffet's", 'ORG'),
#  ('annual', 'DATE'),
#  ('NEW YORK', 'GPE'),
#  ('Reuters', 'ORG'),
#  ('$184 million', 'MONEY'),
#  ('last week', 'DATE'),
#  ('CoinShares', 'ORG'),
#  ('Monday', 'DATE'),
#  ('Friday', 'DATE'),
#  ('more than one-fifth', 'CARDINAL'),
#  ('one', 'CARDINAL'),
#  ('the weekend', 'DATE'),
#  ('below $50,000', 'MONEY'),
#  ('37,720', 'MONEY'),
#  ('only a month', 'DATE'),
#  ('The Bank of England', 'ORG'),
#  ('SAN SALVADOR', 'GPE'),
#  ('Reuters', 'ORG'),
#  ('El Salvador', 'GPE'),
#  ('Nayib Bukele', 'PERSON'),
#  ('Friday', 'DATE'),
#  ('an additional 100', 'CARDINAL'),
#  ('Reuters', 'ORG'),
#  ('Miami', 'GPE'),
#  ('June', 'DATE'),
#  ('Jack Dorsey', 'PERSON'),
#  ('thousands', 'CARDINAL'),
#  ('Twitter', 'PRODUCT'),
#  ('Apple', 'ORG'),
#  ('China', 'GPE'),
#  ('the week to December 10', 'DATE'),
#  ('Ilan Rubens', 'PERSON'),
#  ('Bitcoinfell 9%', 'ORG'),
#  ('the last day', 'DATE'),
#  ('53,978', 'MONEY'),
#  ('the beginning of October this year', 'DATE'),
#  ('Earlier this month', 'DATE'),
#  ('the week to November 26', 'DATE'),
#  ('Ilan Rubens', 'PERSON'),
#  ('HONG KONG', 'GPE'),
#  ('1.5%', 'PERCENT'),
#  ('Asia', 'LOC'),
#  ('Tuesday', 'DATE'),
#  ('Saturday', 'DATE'),
#  ('+1599', 'ORG'),
#  ('SAN SALVADOR', 'GPE'),
#  ('Dec 15', 'DATE'),
#  ('Reuters', 'ORG'),
#  ("El Salvador's", 'GPE'),
#  ('Nayib Bukele', 'PERSON'),
#  ('LONDON', 'GPE'),
#  ('Dec 24', 'DATE'),
#  ('Reuters', 'ORG'),
#  ('Ozan Kose/Getty Images', 'PERSON'),
#  ('Katie Stockton', 'PERSON'),
#  ('Fairlead Strategies', 'ORG'),
#  ('January of 2019', 'DATE'),
#  ('Chase Lochmiller', 'PERSON'),
#  ('Cully Cavness', 'PERSON'),
#  ('Denver', 'GPE'),
#  ('Wyoming', 'GPE'),
#  ('America', 'GPE'),
#  ('MicroStrategy', 'ORG'),
#  ('Michael SaylorJoe Raedle/Getty Images', 'PERSON'),
#  ('MicroStrategy', 'ORG'),
#  ('Michael Saylor', 'PERSON'),
#  ('Andriy Onufriyenko', 'ORG'),
#  ('November', 'DATE'),
#  ('as much as 12%', 'PERCENT'),
#  ('October', 'DATE'),
#  ('year-end', 'DATE'),
#  ('one day', 'DATE'),
#  ('as much as 20%', 'PERCENT'),
#  ('Saturday', 'DATE'),
#  ('months', 'DATE'),
#  ('MarketWatch', 'ORG'),
#  ('18%', 'PERCENT'),
#  ('46,571.84', 'MONEY'),
#  ('this year', 'DATE'),
#  ('BitcoinSean Gladwell', 'ORG'),
#  ('Monday', 'DATE'),
#  ('90%', 'PERCENT'),
#  ('Blockchain.com', 'ORG'),
#  ('12 years', 'DATE'),
#  ('first', 'ORDINAL'),
#  ('about 18.9', 'CARDINAL'),
#  ('Australian', 'NORP'),
#  ('U.S.', 'GPE'),
#  ('$100 million', 'MONEY'),
#  ('NerdWallet', 'ORG'),
#  ('ORLANDO', 'GPE'),
#  ('Fla.', 'GPE'),
#  ('Reuters', 'ORG'),
#  ('U.S.', 'GPE'),
#  ('1982', 'DATE'),
#  ('Nicholas Merten', 'PERSON'),
#  ('May 2018', 'DATE'),
#  ('Latin America', 'LOC'),
#  ('years', 'DATE'),
#  ('El Salvador', 'GPE'),
#  ('Coinbase', 'PERSON'),
#  ('Coinbase', 'ORG'),
#  ('Jack Dorsey', 'PERSON'),
#  ('Mark Zuckerberg', 'PERSON'),
#  ('Rolling Stone', 'ORG'),
#  ('Chez Zuck', 'ORG'),
#  ('Facebook', 'ORG'),
#  ('SAN SALVADOR', 'GPE'),
#  ('Dec 4', 'DATE'),
#  ('Reuters', 'ORG'),
#  ('El Salvador', 'GPE'),
#  ('Nayib Bukele', 'PERSON'),
#  ('Central American', 'NORP'),
#  ('an additional 150', 'CARDINAL'),
#  ('Reuters', 'ORG'),
#  ('the earliest days', 'DATE'),
#  ('last week', 'DATE'),
#  ('El Salvador', 'GPE'),
#  ('Alex Castro', 'PERSON'),
#  ('Verge', 'ORG'),
#  ('the Department of Justice', 'ORG'),
#  ('Ubiquiti', 'PERSON'),
#  ('Reuters', 'ORG'),
#  ('V.N', 'ORG'),
#  ('Wednesday', 'DATE'),
#  ('every day', 'DATE'),
#  ('The U.S. Captioning Company', 'ORG'),
#  ('the British Institute of Verbatim Reporters', 'ORG'),
#  ('Reuters', 'ORG'),
#  ('Germany', 'GPE'),
#  ('more than 1 trillion', 'MONEY'),
#  ('Germans', 'NORP'),
#  ('US', 'GPE'),
#  ('$1 billion', 'MONEY'),
#  ('Summary</li><li>', 'ORG'),
#  ('Companies</li><li>\r\n', 'ORG'),
#  ('documents</li></ul', 'GPE'),
#  ('Reuters', 'ORG'),
#  ('weekend', 'DATE'),
#  ('fifth', 'ORDINAL'),
#  ('$2 billion', 'MONEY'),
#  ('Zuckerbergs', 'ORG'),
#  ('Crypto Rich List', 'PERSON'),
#  ('Reuters', 'ORG'),
#  ('U.S.', 'GPE'),
#  ('ETH', 'ORG'),
#  ('Litecoin', 'PERSON'),
#  ('Monero', 'PERSON'),
#  ('XMR', 'ORG'),
#  ('ATM', 'ORG'),
#  ('House', 'ORG'),
#  ('Bitcoin', 'PERSON'),
#  ('October 19, 2021', 'DATE'),
#  ('REUTERS', 'ORG'),
#  ('Reuters', 'ORG'),
#  ('Britain', 'GPE'),
#  ('ETC Group', 'ORG'),
#  ('Thursday', 'DATE'),
#  ('the weekend', 'DATE'),
#  ('winter', 'DATE'),
#  ('months', 'DATE'),
#  ('December 2017.December 2021', 'DATE'),
#  ('Getty Images', 'GPE'),
#  ('Monday', 'DATE'),
#  ('more than $400 billion', 'MONEY'),
#  ('November 2019', 'DATE'),
#  ('Agrawal', 'PERSON'),
#  ('Twitters', 'NORP'),
#  ('Joseph Lubin', 'PERSON'),
#  ('NEW YORK', 'GPE'),
#  ('Dec 3', 'DATE'),
#  ('Reuters', 'ORG'),
#  ('U.S.', 'GPE'),
#  ('the latest week', 'DATE'),
#  ('mid-June 2019', 'DATE'),
#  ('Reuters', 'ORG'),
#  ('U.S.', 'GPE'),
#  ('Bitcoin, Ethereum', 'ORG'),
#  ('DogeCoin', 'ORG'),
#  ('June 29, 2021', 'DATE'),
#  ('REUTERS', 'ORG'),
#  ('Dado Ruvic/File Photo', 'PERSON'),
#  ('DUBAI', 'ORG'),
#  ('Alexandria Ocasio-Cortez', 'PERSON'),
#  ('New York', 'GPE'),
#  ('J. Scott Applewhite', 'PERSON'),
#  ('Alexandria Ocasio-Cortez', 'PERSON'),
#  ('New York', 'GPE'),
#  ('Democrat', 'NORP'),
#  ('Getty Images', 'ORG'),
#  ('Australian', 'NORP'),
#  ('Peter Foster', 'PERSON'),
#  ('2006', 'DATE'),
#  ('Australian', 'NORP'),
#  ('Peter Foster', 'PERSON'),
#  ('six months', 'DATE'),
#  ('Sydney', 'GPE'),
#  ('Cynthia Lummis', 'PERSON'),
#  ('Republican', 'NORP'),
#  ('Wyoming', 'GPE'),
#  ('Stefani Reynolds/Pool', 'PERSON'),
#  ('REUTERS', 'ORG'),
#  ('Cynthia Lummis', 'PERSON'),
#  ('Pat Toomey', 'PERSON'),
#  ('two', 'CARDINAL'),
#  ('US', 'GPE'),
#  ('2013', 'DATE'),
#  ('British', 'NORP'),
#  ('7,500', 'CARDINAL'),
#  ('Today', 'DATE'),
#  ('$350 million', 'MONEY'),
#  ('CNBC', 'ORG'),
#  ('James Howells', 'PERSON'),
#  ('Wales', 'GPE'),
#  ('Robert Kiyosaki', 'PERSON'),
#  ('The Rich Dad Channel/YouTube', 'ORG'),
#  ('Robert Kiyosaki', 'PERSON'),
#  ('Turkish', 'NORP'),
#  ('Chris McGrath/Getty Images Europe', 'PERSON'),
#  ('Turkish', 'NORP'),
#  ('Turkey', 'GPE'),
#  ('Spencer Platt/Getty Images', 'PERSON'),
#  ('US', 'GPE'),
#  ('Friday', 'DATE'),
#  ('Nasdaq', 'ORG'),
#  ('second', 'ORDINAL'),
#  ('Fed', 'ORG'),
#  ('LONDON', 'GPE'),
#  ('Reuters', 'ORG'),
#  ('last week', 'DATE'),
#  ('Omicron', 'ORG'),
#  ('Greek', 'NORP'),
#  ('Reuters', 'ORG'),
#  ('VALUE', 'ORG'),
#  ('+9188', 'NORP'),
#  ('Reuters', 'ORG'),
#  ('Matthew Heard', 'PERSON'),
#  ('San Jose', 'GPE'),
#  ('33', 'CARDINAL'),
#  ('Kazakhstan', 'GPE'),
#  ('the past week', 'DATE'),
#  ('Shiba Inu', 'ORG'),
#  ('more than 90,000,000%', 'PERCENT'),
#  ('the past year', 'DATE'),
#  ('Getty Images', 'ORG'),
#  ('Cryptocurrencies', 'ORG'),
#  ('Wednesday', 'DATE'),
#  ('50,000', 'MONEY'),
#  ('Visa Inc.', 'ORG'),
#  ('Global Crypto Advisory Practice', 'ORG')]

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
corpus_ethereum = ''
for text in ethereum_sentiment_score['text']:
    corpus_ethereum += text + ' '

# %%
# Run the NER processor on all of the text
tokens_ethereum = nlp(corpus_ethereum)

# Add a title to the document
tokens_ethereum.user_data["title"] = "ETH's News named entity recognition"

# %%
# Render the visualization
displacy.render(tokens_ethereum, style="ent")
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">ETH's News named entity recognition</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Blockchain startup MonoX Finance said on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  that a hacker stole
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $31 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </br>This story originally appeared on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ars Te
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# … [+4372 chars] On
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Budweiser
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  joined the non-fungible token craze with the launch of its
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  collection of unique pieces of digital art  depictions of beer cans that sold for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hundreds of dollars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </br>Dub… [+1512 chars]
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Earlier this year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , Nothing released a pair of relatively cheap $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     99
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  Ear 1 earbuds with a fun transparent case, wireless charging and decent sound quality. Now, the company (created by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     OnePlus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  cofounde… [+1395 chars] White Castle double cheeseburger.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Erin McDowell/Insider
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Fast food chain
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     White Castle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  announced on
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  that it registered a domain name with th… [+1012 chars]
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nicholas Merten
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  , an expert in cryptography, predicts that the digital currency ethereum will overtake bitcoin in the market after reaching its highest value since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May 2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . He clarified that these e… [+769 chars] While people around the world still searched for information about the COVID-19 pandemic, other topics dominated
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's Year in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Search
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  like cricket and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Squid Game
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . Matches for the T20 Worl… [+2053 chars] The wait is finally over. After a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     year-long
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  delay,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Xboxs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  iconic hero, Master Chief, is back. With
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Halo Infinite
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , there are new toys and fight mechanics, while many players will also benefit

# %%
# List all Entities
list_ent_eth = [(ent.text , ent.label_) for ent in tokens_ethereum.ents if not ent.label_ == ("CARDINAL" and 'MONEY') ]
list_ent_eth
# Out:
# [('Wednesday', 'DATE'),
#  ('Ars Te', 'ORG'),
#  ('Monday', 'DATE'),
#  ('Budweiser', 'ORG'),
#  ('first', 'ORDINAL'),
#  ('Earlier this year', 'DATE'),
#  ('OnePlus', 'ORG'),
#  ('Erin McDowell/Insider', 'PERSON'),
#  ('White Castle', 'FAC'),
#  ('Twitter', 'PRODUCT'),
#  ('Nicholas Merten', 'PERSON'),
#  ('May 2018', 'DATE'),
#  ('Google', 'ORG'),
#  ('Search', 'GPE'),
#  ('2021', 'DATE'),
#  ('Squid Game', 'ORG'),
#  ('year-long', 'DATE'),
#  ('Xboxs', 'ORG'),
#  ('Halo Infinite', 'ORG'),
#  ('MicroStrategy', 'ORG'),
#  ('Michael SaylorJoe Raedle/Getty Images', 'PERSON'),
#  ('ETF', 'ORG'),
#  ('December 13th', 'DATE'),
#  ('The Ear 1', 'WORK_OF_ART'),
#  ('Nothings Ear 1', 'PERSON'),
#  ('earlier this year', 'DATE'),
#  ('DeFi', 'GPE'),
#  ('Ethereum', 'ORG'),
#  ('DeFi', 'GPE'),
#  ('The U.S. Captioning Company', 'ORG'),
#  ('the British Institute of Verbatim Reporters', 'ORG'),
#  ('Bitcoin', 'PERSON'),
#  ('Saturday', 'DATE'),
#  ('the weekend', 'DATE'),
#  ('Bitmar', 'GPE'),
#  ('Bitcoin, Ethereum', 'ORG'),
#  ('DogeCoin', 'ORG'),
#  ('June 29, 2021', 'DATE'),
#  ('REUTERS', 'ORG'),
#  ('Dado Ruvic/File Photo', 'PERSON'),
#  ('DUBAI', 'ORG'),
#  ('Angerer/Getty Images', 'ORG'),
#  ('Budweiser', 'ORG'),
#  ('first', 'ORDINAL'),
#  ('NFT', 'ORG'),
#  ('Monday', 'DATE'),
#  ('Bitcoin', 'PERSON'),
#  ('October 19, 2021', 'DATE'),
#  ('REUTERS', 'ORG'),
#  ('Reuters', 'ORG'),
#  ('9.29%', 'PERCENT'),
#  ('Dec 4', 'DATE'),
#  ('Reuters', 'ORG'),
#  ('8.4%', 'PERCENT'),
#  ('20:01', 'CARDINAL'),
#  ('Saturday', 'DATE'),
#  ('Bitcoin', 'PERSON'),
#  ('28.7%', 'PERCENT'),
#  ('November 29, 2021', 'DATE'),
#  ('REUTERS', 'ORG'),
#  ('Dado Ruvic/IllustrationDec', 'PERSON'),
#  ('12', 'CARDINAL'),
#  ('Reuters', 'ORG'),
#  ('Sunday', 'DATE'),
#  ('Reuters', 'ORG'),
#  ('5.5%', 'PERCENT'),
#  ('22:04', 'CARDINAL'),
#  ('Friday', 'DATE'),
#  ('Bitcoin', 'PERSON'),
#  ('22.6%', 'PERCENT'),
#  ('CNBC', 'ORG'),
#  ('BitMart', 'ORG'),
#  ('Satur', 'PERSON'),
#  ('Getty Images', 'ORG'),
#  ('Cryptocurrencies', 'ORG'),
#  ('Wednesday', 'DATE'),
#  ('every day', 'DATE'),
#  ('NurPhoto/Getty Images', 'ORG'),
#  ('Robinhood', 'ORG'),
#  ('Thursday', 'DATE'),
#  ('seven', 'CARDINAL'),
#  ('Youtube/Grand Amphi Théatre', 'ORG'),
#  ('Ethereum', 'ORG'),
#  ('ETH', 'ORG'),
#  ('Vitalik Buterin', 'PERSON'),
#  ('Ethereum Improvement Proposal', 'ORG'),
#  ('EIP', 'ORG'),
#  ('Ethereum', 'ORG'),
#  ('NFT', 'ORG'),
#  ('Some months ago', 'DATE'),
#  ('NFT', 'ORG'),
#  ('7', 'CARDINAL'),
#  ('7', 'CARDINAL'),
#  ('Blockchain', 'PERSON'),
#  ('Wednesday', 'DATE'),
#  ('Zuckerbergs', 'ORG'),
#  ('Crypto Rich List', 'PERSON'),
#  ('Coinbase', 'PERSON'),
#  ('Kraken', 'ORG'),
#  ('Kraken', 'ORG'),
#  ('Unlike Kraken', 'PERSON'),
#  ('the U.S. Securities and Exchange Commission', 'ORG'),
#  ('Reuters', 'ORG'),
#  ('Australia', 'GPE'),
#  ('Wednesday', 'DATE'),
#  ('daily', 'DATE'),
#  ('Cryptocurrencies', 'ORG'),
#  ('this weekend', 'DATE'),
#  ('14%', 'PERCENT'),
#  ('the weekend', 'DATE'),
#  ('an hour', 'TIME'),
#  ('NFT', 'ORG'),
#  ('April 2021', 'DATE'),
#  ('Dec 9', 'DATE'),
#  ('Reuters', 'ORG'),
#  ('Studio', 'PERSON'),
#  ('Thursday', 'DATE'),
#  ("Microsoft Corp's", 'ORG'),
#  ('M12', 'PRODUCT'),
#  ('Reuters', 'ORG'),
#  ('Germany', 'GPE'),
#  ('Germans', 'NORP'),
#  ('Reuters', 'ORG'),
#  ('one', 'CARDINAL'),
#  ('2021', 'CARDINAL'),
#  ('Tues', 'PERSON'),
#  ('Dec 1', 'DATE'),
#  ('Reuters', 'ORG'),
#  ('Thailand', 'GPE'),
#  ('Wednesday', 'DATE'),
#  ('Dec 16', 'DATE'),
#  ('Reuters', 'ORG'),
#  ('Nansen', 'ORG'),
#  ('Thursday', 'DATE'),
#  ('Accel', 'PRODUCT'),
#  ('Andreessen Horowitz', 'PERSON'),
#  ('this year', 'DATE'),
#  ('Andreessen', 'PERSON'),
#  ('hours', 'TIME'),
#  ('Another year', 'DATE'),
#  ('Google’s', 'ORG'),
#  ('Search Trends', 'GPE'),
#  ('Google', 'ORG'),
#  ('Richerd/OpenSea', 'ORG'),
#  ('NFT', 'ORG'),
#  ('one', 'CARDINAL'),
#  ('first', 'ORDINAL'),
#  ('CryptoPunks', 'ORG'),
#  ('Solana', 'PERSON'),
#  ('DApps', 'ORG'),
#  ('DApps', 'ORG'),
#  ('South Park', 'LOC'),
#  ('StyledSnail', 'ORG'),
#  ('Dear Life', 'WORK_OF_ART'),
#  ('Bakkt', 'PERSON'),
#  ('Nipitpon Singad/', 'PERSON'),
#  ('EyeEm/Getty', 'ORG'),
#  ('HackerThana Prasongsin', 'ORG'),
#  ('Crypto', 'PERSON'),
#  ('BitMart', 'ORG'),
#  ('Wednesday', 'DATE'),
#  ('three days', 'DATE'),
#  ('Kardashians', 'NORP'),
#  ('DeFi', 'GPE'),
#  ('Steven Cohen', 'PERSON'),
#  ('Forty-year-o', 'DATE'),
#  ('Jakub Porzycki/Getty ImagesJakub Porzycki/Getty Images', 'PERSON'),
#  ('Robinhood', 'ORG'),
#  ('Wednesday', 'DATE'),
#  ('INA FASSBENDER/AFP', 'ORG'),
#  ('Getty ImagesINA FASSBENDER/AFP', 'ORG'),
#  ('Getty Images', 'ORG'),
#  ('Citigroup', 'ORG'),
#  ('Robert Kiyosaki', 'PERSON'),
#  ('The Rich Dad Channel/YouTube', 'ORG'),
#  ('Robert Kiyosaki', 'PERSON'),
#  ('Bitcoin, Ethereum', 'ORG'),
#  ('DogeCoin', 'ORG'),
#  ('June 29, 2021', 'DATE'),
#  ('REUTERS', 'ORG'),
#  ('Dado Ruvic', 'PERSON'),
#  ('Reuters', 'ORG'),
#  ('Monday', 'DATE'),
#  ('this week', 'DATE'),
#  ("the U.S. Federal Reserve's", 'ORG'),
#  ('NEW YORK', 'GPE'),
#  ('Reuters', 'ORG'),
#  ('last week', 'DATE'),
#  ('CoinShares', 'ORG'),
#  ('Monday', 'DATE'),
#  ('Friday', 'DATE'),
#  ('Reuters', 'ORG'),
#  ('2021', 'DATE'),
#  ('Wednesday', 'DATE'),
#  ('NEW YORK', 'GPE'),
#  ('Reuters', 'ORG'),
#  ('Brazilian', 'NORP'),
#  ('Latin America', 'LOC'),
#  ('blockchain compani', 'PERSON'),
#  ('NEW YORK', 'GPE'),
#  ('Reuters', 'ORG'),
#  ('Asian', 'NORP'),
#  ('Assembly', 'ORG'),
#  ('DeFi', 'GPE'),
#  ('DeFi', 'GPE'),
#  ('develo', 'PERSON'),
#  ('one', 'CARDINAL'),
#  ('DeFi', 'GPE'),
#  ('more than one-fifth', 'CARDINAL'),
#  ('one', 'CARDINAL'),
#  ('the weekend', 'DATE'),
#  ('only a month', 'DATE'),
#  ('three', 'CARDINAL'),
#  ('Ubisoft', 'ORG'),
#  ('Blockchain', 'GPE'),
#  ('NFT', 'ORG'),
#  ('M12', 'PRODUCT'),
#  ('Microsoft', 'ORG'),
#  ('Palm NFT Studio', 'ORG'),
#  ('Ethereum', 'ORG'),
#  ('Palm', 'ORG'),
#  ('NFT', 'ORG'),
#  ('Palm', 'ORG'),
#  ('Cryptocurrencies', 'ORG'),
#  ('over a decade', 'DATE'),
#  ('Ubisoft', 'ORG'),
#  ('NFT', 'ORG'),
#  ('first', 'ORDINAL'),
#  ('Ubisoft', 'GPE'),
#  ('this week', 'DATE'),
#  ('Non-fung', 'ORG'),
#  ('724,948', 'CARDINAL'),
#  ('tomorrow', 'DATE'),
#  ('Facebook Gaming', 'PRODUCT'),
#  ('2nd', 'ORDINAL'),
#  ('Annual GamesBeat &', 'ORG'),
#  ('Facebook Gaming Summit | GamesBeat', 'PRODUCT'),
#  ('January 25-27, 2022', 'DATE'),
#  ('the next era', 'DATE'),
#  ('Facebook', 'PRODUCT'),
#  ('Twitter', 'PRODUCT'),
#  ('Last night', 'TIME'),
#  ('one', 'CARDINAL'),
#  ('Sheldon Xia', 'PERSON'),
#  ('Twitter', 'PRODUCT'),
#  ('Shiba Inu', 'ORG'),
#  ('more than 90,000,000%', 'PERCENT'),
#  ('the past year', 'DATE'),
#  ('AP Photo/Shizuo Kambayashi', 'ORG'),
#  ('Kraken', 'ORG'),
#  ('nearly a month', 'DATE'),
#  ('Twitter', 'PRODUCT'),
#  ('Flexpool', 'ORG'),
#  ('year-long', 'DATE'),
#  ('Xboxs', 'ORG'),
#  ('Halo Infinite', 'ORG'),
#  ('Omicron', 'ORG'),
#  ('Monday', 'DATE'),
#  ('Grammy', 'PERSON'),
#  ('Billie Eilish', 'PERSON'),
#  ('Philadelphia Eagles', 'ORG'),
#  ('Jason Kelce', 'PERSON'),
#  ('Alex Dobie', 'PERSON'),
#  ('Android Central', 'ORG'),
#  ('Carl Pei-', 'PERSON'),
#  ('Nothing', 'ORG'),
#  ('today', 'DATE'),
#  ('1', 'CARDINAL'),
#  ('recent weeks', 'DATE'),
#  ('The Bank of England', 'ORG'),
#  ('National Basketball Association', 'ORG'),
#  ('Stephen Curry', 'PERSON'),
#  ('2,974', 'CARDINAL'),
#  ('3', 'CARDINAL'),
#  ('American Express', 'ORG'),
#  ('TIME', 'ORG'),
#  ('weekly', 'DATE'),
#  ('Last Dece', 'DATE'),
#  ('the Jim Henson Company', 'ORG'),
#  ('first', 'ORDINAL'),
#  ('Labyrinth', 'ORG'),
#  ('ETH', 'ORG'),
#  ('second', 'ORDINAL'),
#  ('about 453%', 'PERCENT'),
#  ('this year', 'DATE'),
#  ('Ethereum', 'ORG'),
#  ('David Solomon', 'PERSON'),
#  ('Goldman Sachs', 'ORG'),
#  ('Matt Winkelmeyer', 'PERSON'),
#  ('Getty Images', 'ORG'),
#  ('the next couple of years', 'DATE'),
#  ('10', 'CARDINAL'),
#  ('the Opening Bell', 'ORG'),
#  ('tomorrow', 'DATE'),
#  ('Monday', 'DATE'),
#  ('holidays', 'DATE'),
#  ('DeFi', 'GPE'),
#  ('one', 'CARDINAL'),
#  ('only 24', 'CARDINAL'),
#  ('CryptoPunks', 'ORG'),
#  ('2,500', 'CARDINAL'),
#  ('USD', 'ORG'),
#  ('Thursday', 'DATE'),
#  ('NFT', 'ORG'),
#  ('Cryptopunks', 'PERSON'),
#  ('] Sam Bankman-Fried', 'PERSON'),
#  ('FTX', 'ORG'),
#  ('2019', 'DATE'),
#  ('CEO.FTX\r\nBull', 'ORG'),
#  ('January 2001', 'DATE'),
#  ('Wikipedias', 'PERSON'),
#  ('Hello', 'GPE'),
#  ('World', 'ORG'),
#  ('2021', 'DATE'),
#  ('this year', 'DATE'),
#  ('Ethereum', 'ORG'),
#  ('ADA', 'ORG'),
#  ('Ethereum', 'ORG'),
#  ('ETH', 'ORG'),
#  ('second', 'ORDINAL'),
#  ('today', 'DATE'),
#  ('2:31 p.m. ET', 'TIME'),
#  ('Ethereu', 'GPE'),
#  ('ETH', 'ORG'),
#  ('today', 'DATE'),
#  ('Ethereum', 'ORG'),
#  ('as much as 4.9%', 'PERCENT'),
#  ('the last 24 hours', 'TIME'),
#  ('Thursday', 'DATE'),
#  ('Distributed Ledger', 'PERSON'),
#  ('weekly', 'DATE'),
#  ('Frances Yue', 'PERSON'),
#  ('MarketWatch', 'ORG'),
#  ('Ill', 'GPE')]

# %% [markdown]
# ---
